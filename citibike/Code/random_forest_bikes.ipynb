# %%
import pandas as pd
import sklearn.model_selection as ms
import sklearn
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.model_selection import KFold 
from sklearn.model_selection import StratifiedKFold
import pydot
import os
from sklearn.tree import export_graphviz
import six
from sklearn import tree

# %%
df = pd.read_csv("workable_df.csv")

# %%
#Only use trips that last less than 1 hour.
df = df[df['trip_duration']<3600]
#Cast categorical variables to strings.
df.gender = df['gender'].apply(str)
df.user_type = df['user_type'].apply(str)
df.start_station_id = df['start_station_id'].apply(str)
#Median sale price has lots of N/A values. Remove this column.
df = df.drop('median_sale_price', axis = 1)
#Remove the few rows that still have N/A values. 
df = df.dropna(axis=0)
# Confirm types are as desired.
df.dtypes
# Out:
# trip_duration                      int64
# start_month                        int64
# start_hour                         int64
# start_station_id                  object
# user_type                         object
# birth_year                         int64
# gender                            object
# total_precipitation_inches       float64
# average_temperature_farenheit    float64
# total_snowfall_inches            float64
# median_rental_price              float64
# week_day                          object
# start_hour_sq                      int64
# start_month_sq                     int64
# dtype: object

# %%
#One hot encode dataset. 
df = pd.get_dummies(df,drop_first=True)

# %%
#Split data into test and training sets.
y = df['trip_duration']
X = df.drop('trip_duration', axis = 1)
feature_names = X.columns
X_train, X_test, y_train, y_test = ms.train_test_split(X, y, test_size=0.2, random_state=74)

# %%
#Fit initial random forest model
rf = RandomForestRegressor(n_estimators = 3, random_state = 32)
#Train the model on training data
rf.fit(X_train, y_train);
#Find predicted trip durations in test set.
y_pred = list(rf.predict(X_test))
#MAE
sum(abs(y_pred-y_test)) / len(y_test)
# Out:
# 444.01133646475245

# %%
#Show feature importances for manual feature selection.
fi_df = pd.DataFrame(list(zip(feature_names, rf.feature_importances_)))

# %%
fi_df.sort_values(by = 1, ascending = False)
# Out:
#                                  0             1
# 2                       birth_year  1.114142e-01
# 4    average_temperature_farenheit  1.100218e-01
# 747         user_type_"Subscriber"  8.574517e-02
# 6              median_rental_price  5.123329e-02
# 1                       start_hour  4.706160e-02
# 7                    start_hour_sq  4.683126e-02
# 3       total_precipitation_inches  4.600186e-02
# 0                      start_month  2.185305e-02
# 8                   start_month_sq  2.163896e-02
# 754               week_day_Tuesday  1.054175e-02
# 753              week_day_Thursday  1.036473e-02
# 755             week_day_Wednesday  1.028747e-02
# 750                week_day_Monday  9.659183e-03
# 751              week_day_Saturday  8.849745e-03
# 752                week_day_Sunday  8.822402e-03
# 748                       gender_1  4.909155e-03
# 749                       gender_2  3.310750e-03
# 5            total_snowfall_inches  2.964653e-03
# 718           start_station_id_514  1.906640e-03
# 707           start_station_id_499  1.731030e-03
# 698           start_station_id_490  1.722457e-03
# 722           start_station_id_519  1.716877e-03
# 80            start_station_id_281  1.601566e-03
# 91           start_station_id_3002  1.532280e-03
# 32           start_station_id_2006  1.493980e-03
# 243          start_station_id_3255  1.481852e-03
# 626           start_station_id_402  1.408071e-03
# 705           start_station_id_497  1.394470e-03
# 202          start_station_id_3164  1.393263e-03
# 687           start_station_id_477  1.367497e-03
# ..                             ...           ...
# 598          start_station_id_3718  6.678854e-05
# 462          start_station_id_3512  6.353013e-05
# 538          start_station_id_3621  6.336646e-05
# 434          start_station_id_3485  6.073242e-05
# 404          start_station_id_3432  5.935592e-05
# 18            start_station_id_152  5.916676e-05
# 446          start_station_id_3498  5.562313e-05
# 311          start_station_id_3340  5.516706e-05
# 296          start_station_id_3325  5.438636e-05
# 165          start_station_id_3128  5.349673e-05
# 31           start_station_id_2005  5.334064e-05
# 535          start_station_id_3619  5.180665e-05
# 233          start_station_id_3238  4.853688e-05
# 313          start_station_id_3342  4.617656e-05
# 501          start_station_id_3557  4.195831e-05
# 541          start_station_id_3625  4.031388e-05
# 366          start_station_id_3394  4.023896e-05
# 602          start_station_id_3721  2.634491e-05
# 595          start_station_id_3714  2.565136e-05
# 367          start_station_id_3395  1.984818e-05
# 551          start_station_id_3642  1.710142e-05
# 537          start_station_id_3620  1.630111e-05
# 428          start_station_id_3468  1.606676e-05
# 599          start_station_id_3719  1.178523e-05
# 304          start_station_id_3333  8.480738e-06
# 575          start_station_id_3683  1.642421e-06
# 597          start_station_id_3716  9.583861e-07
# 590          start_station_id_3704  7.577806e-07
# 601          start_station_id_3720  4.238889e-08
# 235          start_station_id_3240  0.000000e+00
#
# [756 rows x 2 columns]

# %%
#Try model only with features with importance scores of > .01
X2 = df[['birth_year', 'average_temperature_farenheit', 'user_type_"Subscriber"', 'median_rental_price', 'start_hour', 'total_precipitation_inches', 'start_month']]
feature_names = X2.columns
X_train, X_test, y_train, y_test = ms.train_test_split(X2, y, test_size=0.2, random_state=74)

# %%
#Fit random forest model. Increase number of estimaters. 
rf2 = RandomForestRegressor(n_estimators = 50, random_state = 32)
#Train the model on training data
rf2.fit(X_train, y_train);
#Find predicted trip durations in test set.
y_pred = list(rf2.predict(X_test))
#MAE
sum(abs(y_pred-y_test)) / len(y_test)
# Out:
# 428.81771548262105

# %%
#Fit random forest model. Optimized parameters and feature selection.
rf3 = RandomForestRegressor(n_estimators = 100, random_state = 22, oob_score = True, bootstrap = True, max_depth = 90, max_features = 'sqrt', min_samples_leaf = 3, min_samples_split = 5)
#Train the model on training data
rf3.fit(X_train, y_train);
#Find predicted trip durations in test set.
y_pred = list(rf3.predict(X_test))
train_pred = list(rf3.predict(X_train))
#MAE Test 
sum(abs(y_pred-y_test)) / len(y_test)
# MAE Train. 
#Train set error very close to test set error. We are not overfit.
sum(abs(train_pred-y_train)) / len(y_train)
# Out:
# 372.57408978342266

# %%
# Final feature importance. 
fi_df = pd.DataFrame(list(zip(feature_names, rf3.feature_importances_)))
fi_df.sort_values(by = 1, ascending = False)
# Out:
#                                0         1
# 1  average_temperature_farenheit  0.230666
# 0                     birth_year  0.206453
# 3            median_rental_price  0.167736
# 2         user_type_"Subscriber"  0.141789
# 4                     start_hour  0.125079
# 5     total_precipitation_inches  0.079813
# 6                    start_month  0.048464

# %%
from sklearn.tree import export_graphviz

# %%
# Create dot file of a tree from final forest. (Too big to visualize in final report.)
export_graphviz(rf3.estimators_[0],
                feature_names=feature_names,
                filled=True,
                rounded=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-847424fc597a> in <module>
#       2                 feature_names=feature_names,
#       3                 filled=True,
# ----> 4                 rounded=True)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     425                                  "does not match number of features, %d"
#     426                                  % (len(feature_names),
# --> 427                                     decision_tree.n_features_))
#     428
#     429         # The depth of each node for plotting with 'leaf' option
#
# ValueError: Length of feature_names, 756 does not match number of features, 7
